# %%
import sys
import matplotlib.pyplot as plt
import cv2
from data import voc_data_helpers
# %matplotlib inline                               
# %load_ext autoreload
# %autoreload 2

# Load the "autoreload" extension
# %load_ext autoreload

# always reload modules marked with "%aimport"
# %autoreload 1

import os
import sys

# add the 'src' directory as one where we can import modules
src_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(src_dir)

import keras
from keras.layers.convolutional import Conv2D
from keras.models import Model
from models.vgg16_network import vgg16_rpn
import train_rpn

print(sys.version)
# Out:
# Using TensorFlow backend.
# [{'ymax': 339, 'name': 'chair', 'xmax': 324, 'ymin': 211, 'xmin': 263}, {'ymax': 372, 'name': 'chair', 'xmax': 253, 'ymin': 264, 'xmin': 165}, {'ymax': 374, 'name': 'chair', 'xmax': 67, 'ymin': 244, 'xmin': 5}, {'ymax': 299, 'name': 'chair', 'xmax': 295, 'ymin': 194, 'xmin': 241}, {'ymax': 220, 'name': 'chair', 'xmax': 312, 'ymin': 186, 'xmin': 277}]
# cnn height: 37 cnn width: 50
# 3.5.4 |Continuum Analytics, Inc.| (default, Aug 14 2017, 12:43:10)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %%
print(keras.backend.common.image_data_format())
ANCHOR_SIZES = np.array([128, 256, 512])
ANCHOR_RATIOS = np.array([[1,1], [1,2], [2,1]])

ANCHORS = np.array([size * ratio for size in ANCHOR_SIZES for ratio in ANCHOR_RATIOS])
# Out:
# channels_last
# [autoreload of src.train_rpn failed: Traceback (most recent call last):
#   File "/Users/ke/miniconda3/envs/capstone/lib/python3.5/site-packages/IPython/extensions/autoreload.py", line 246, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/ke/miniconda3/envs/capstone/lib/python3.5/site-packages/IPython/extensions/autoreload.py", line 369, in superreload
#     module = reload(module)
#   File "/Users/ke/miniconda3/envs/capstone/lib/python3.5/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/Users/ke/miniconda3/envs/capstone/lib/python3.5/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "/Users/ke/mlnd/capstone_project/src/train_rpn.py", line 1, in <module>
# ...

# %%
a = keras.applications.vgg16.VGG16(include_top=False, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)

# %%
[img, metadata] = voc_data_helpers.extract_img_data('/Users/ke/Downloads/VOCdevkit/VOC2007', '000005')
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(cv_rgb)
# Out:
# [{'ymax': 339, 'name': 'chair', 'ymin': 211, 'xmin': 263, 'xmax': 324}, {'ymax': 372, 'name': 'chair', 'ymin': 264, 'xmin': 165, 'xmax': 253}, {'ymax': 374, 'name': 'chair', 'ymin': 244, 'xmin': 5, 'xmax': 67}, {'ymax': 299, 'name': 'chair', 'ymin': 194, 'xmin': 241, 'xmax': 295}, {'ymax': 220, 'name': 'chair', 'ymin': 186, 'xmin': 277, 'xmax': 312}]

# %%
#a.layers.pop()
a.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
x = Conv2D(512, (3, 3), padding='same', activation='relu', kernel_initializer='normal', name='rpn_conv1')(a.output)
x_class = Conv2D(9, (1, 1), activation='sigmoid', kernel_initializer='uniform', name='rpn_out_class')(x)
x_regr = Conv2D(9 * 4, (1, 1), activation='linear', kernel_initializer='zero', name='rpn_out_regress')(x)

b = Model(inputs=a.inputs, outputs=[x_class,x_regr])

# %%
model = vgg16_rpn(num_classes = 10)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_6 (InputLayer)             (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, None, None, 64 1792        input_6[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Conv2D)            (None, None, None, 64 36928       block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_pool (MaxPooling2D)       (None, None, None, 64 0           block1_conv2[0][0]
# ____________________________________________________________________________________________________
# ...
