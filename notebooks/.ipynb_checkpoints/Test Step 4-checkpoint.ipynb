# %%
# Load the "autoreload" extension
# %load_ext autoreload

# %autoreload 2

import os
import sys

# add the 'src' directory as one where we can import modules
src_dir = os.path.join(os.getcwd(), os.pardir, 'faster_rcnn')
sys.path.append(src_dir)

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import math
import cv2
from shapes import Image
from data import voc_data_helpers
from data.voc_data_helpers import extract_img_data
from det_util import DetTrainingManager
from shared_constants import RESIZE_MIN_SIZE, RESIZE_MAX_SIZE
from util import transform
# %matplotlib inline




import keras
from keras import backend as K
from keras.layers import Input, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.models import Model, model_from_json
from keras.optimizers import SGD
import resnet
from resnet import resnet50_rpn, resnet50_classifier, resnet50_base, preprocess, pop_layer, resnet101_base, resnet50_rpn, resnet101_base, resnet101_rpn, resnet101_classifier
import vgg
from vgg import vgg16_rpn, vgg16_classifier, vgg16_base
from custom_layers import RoiResizeConv
from data import voc_data_helpers
from loss_functions import cls_loss_rpn, bbreg_loss_rpn, cls_loss_det, bbreg_loss_det

VOC_PATH = '/Users/ke/Downloads/VOCdevkit/VOC2007'

NUM_ROIS = 64

print(sys.version)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 3.5.4 |Continuum Analytics, Inc.| (default, Aug 14 2017, 12:43:10)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %%
rpn = resnet.rpn_from_h5('../models/rpn_model_r50_noreg_step3_kitti_trainval.h5')
# Out:
# /Users/ke/miniconda3/envs/capstone/lib/python3.5/site-packages/keras/models.py:251: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
detector = resnet.det_from_h5('../models/detector_model_r50_noreg_step4_kitti_trainval.h5', 10)

# %%
voc_path = '/Users/ke/mlnd/tmp/kitti/voc_format/kitti_test/'
class_mapping = voc_data_helpers.KITTI_CLASS_MAPPING
image = voc_data_helpers.extract_img_data(voc_path, '000018')
image, resized_ratio = image.resize_within_bounds(600, 1500)
batched_img = np.expand_dims(image.data, axis=0)
preprocessed = preprocess(image.data)
batched_preprocessed = np.expand_dims(preprocessed, axis=0)

# %%
rgb_data = cv2.cvtColor(image.data, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(16,16))
plt.imshow(rgb_data)

# %%
manager = DetTrainingManager(rpn_model=rpn, class_mapping=class_mapping, preprocess_func=preprocess)

# %%
rpn_input, rois_r50, y_class_num, y_transform = manager.get_training_input(image)

# %%
cls_out, reg_out = detector.predict_on_batch([rpn_input, rois_r50])

# %%
print(rois_r50)
print(np.argmax(cls_out[0,0:64], axis=1))
idx = 0
cls_num = 0
print(rois_r50[0,idx])
print(rois_r50[0,idx] * 16)
bbreg = reg_out[0,idx,4*cls_num:4*(cls_num+1)] / np.array([10, 10, 5, 5])
print(bbreg)
print(transform(rois_r50[0,idx] * 16, bbreg))
new_coords = [transform(rois_r50[0,idx], bbreg)]

# %%
import matplotlib.gridspec as gridspec

fig,ax = plt.subplots(1, figsize=(16, 16))
ax.imshow(rgb_data)

for x1,y1,x2,y2 in rois_r50[0,idx:idx+1]:
# for x1,y1,w,h in rois_r50[0,0:32]:
    x = x1 * 16
    y = y1 * 16
    w = (x2 - x1) * 16
    h = (y2 - y1) * 16
    rect = patches.Rectangle((x, y), w, h, linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)
    
print(new_coords)
for x1,y1,x2,y2 in new_coords:
    x = x1 * 16
    y = y1 * 16
    w = (x2 - x1) * 16
    h = (y2 - y1) * 16
    rect = patches.Rectangle((x, y), w, h, linewidth=1,edgecolor='b',facecolor='none')
    ax.add_patch(rect)

# %%
(np.array(new_coords)*16)/resized_ratio

# %%
fig,ax = plt.subplots(1, figsize=(16, 16))
ax.imshow(rgb_data)

for gt_box in image.gt_boxes:
    x, y, w, h = gt_box.corner_dims
    rect = patches.Rectangle((x, y), w, h, linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)
    label = gt_box.obj_cls 
    ax.text(x+w/2, y+h, label, ha="center", va="top", rotation=0,
            size=15,
            color='red',
            bbox=None)

# %%
resized_ratio

# %%
from voc_dets import get_dets, get_dets_by_cls
dets = get_dets(manager, detector, image, resized_ratio, det_threshold=0.0)
# dets2 = get_dets_by_cls(manager, detector, [resized_ratio], [image], stride=16, det_threshold=0.0)
# Out:
# Executed function get_det_inputs in 2.3332306570082437 seconds
#     Executed function nms in 0.04414458198880311 seconds
#     Executed function _get_valid_box_idxs in 0.000305854991893284 seconds
#     Executed function _rois_from_image in 2.2768159539991757 seconds
#         Executed function _get_rois in 0.016296781002893113 seconds
#             Executed function _get_rois in 0.016289025006699376 seconds
#                 Executed function _sanitize_boxes_inplace in 0.006510730003356002 seconds
#                 Executed function transform_np_inplace in 0.002434103997074999 seconds
#                 Executed function _get_anchor_coords in 0.0016554769972572103 seconds
#         Executed function _out_from_image in 2.2311021799978334 seconds
#         Executed function batched_image in 0.026427616001456045 seconds
# num rois: 300
# Executed function nms in 0.00028044599457643926 seconds
# Executed function nms in 7.091800216585398e-05 seconds
# Executed function nms in 6.334300269372761e-05 seconds
# Executed function nms in 9.385900921188295e-05 seconds

# %%
dets
# Out:
# [{'bbox': array([ 50, 208, 202, 262]), 'cls_name': 'car', 'prob': 0.99989057},
#  {'bbox': array([ 917,  186, 1238,  374]),
#   'cls_name': 'car',
#   'prob': 0.99979967},
#  {'bbox': array([404, 188, 472, 209]), 'cls_name': 'car', 'prob': 0.99954152},
#  {'bbox': array([789, 176, 978, 304]), 'cls_name': 'car', 'prob': 0.99882382},
#  {'bbox': array([  0, 214,  72, 276]), 'cls_name': 'car', 'prob': 0.99489731},
#  {'bbox': array([579, 181, 610, 198]), 'cls_name': 'car', 'prob': 0.9676916},
#  {'bbox': array([706, 178, 784, 241]), 'cls_name': 'car', 'prob': 0.96145242},
#  {'bbox': array([696, 180, 755, 226]), 'cls_name': 'car', 'prob': 0.95453846},
#  {'bbox': array([144, 195, 213, 226]), 'cls_name': 'car', 'prob': 0.74167925},
#  {'bbox': array([467, 185, 493, 200]), 'cls_name': 'car', 'prob': 0.49607438},
#  {'bbox': array([272, 183, 351, 215]),
#   'cls_name': 'DontCare',
#   'prob': 0.49314496},
#  {'bbox': array([329, 175, 408, 211]), 'cls_name': 'Van', 'prob': 0.51504201},
#  {'bbox': array([667, 161, 720, 213]), 'cls_name': 'Misc', 'prob': 0.99979252}]

# %%
fig,ax = plt.subplots(1, figsize=(16, 16))
ax.imshow(rgb_data)

for det in dets:
    x, y, w, h = np.array([det['bbox'][0], det['bbox'][1], det['bbox'][2] - det['bbox'][0], det['bbox'][3] - det['bbox'][1]])*resized_ratio
    rect = patches.Rectangle((x, y), w, h, linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)
    label = "{} {:6.2f}".format(det['cls_name'], det['prob'])
    ax.text(x+w/2, y+h, label, ha="center", va="top", rotation=0,
            size=15,
            color='red',
            bbox=None)

# %%
detector.summary()
