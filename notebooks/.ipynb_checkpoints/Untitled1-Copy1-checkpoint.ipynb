# %%
# Load the "autoreload" extension
# %load_ext autoreload

# %autoreload 2

import os
import sys

# add the 'src' directory as one where we can import modules
src_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(src_dir)

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import math
import cv2
from data import voc_data_helpers
from data.voc_data_helpers import get_img_sets, extract_img_data
from minibatch import get_rois, nms, get_ious, calc_iou, rpn_y_true_batch, get_rois_3, ANCHOR_DIMS, det_y_true_batch_3
from train_rpn import RESIZE_MIN_SIDE
from util import resized_dims, transform
# %matplotlib inline




import keras
from keras.layers import Input
from keras.layers.convolutional import Conv2D
from keras.models import Model, model_from_json
from keras.optimizers import SGD
from vgg16 import vgg16_rpn, vgg16_classifier, vgg16_base
from vgg16_dets import get_dets
from custom_layers import RoiResizeConv
from data import voc_data_helpers
from map_util import get_map
from loss_functions import cls_loss_rpn, bbreg_loss_rpn, cls_loss_det, bbreg_loss_det
import train_rpn

NUM_CLASSES_VOC = 20
DEFAULT_NUM_ITERATIONS = 10
DEFAULT_LEARN_RATE = 1e-3
DEFAULT_MOMENTUM = 0.9
VOC_PATH = '/Users/ke/Downloads/VOCdevkit/VOC2007'

NUM_ROIS = 64

print(sys.version)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 3.5.4 |Continuum Analytics, Inc.| (default, Aug 14 2017, 12:43:10)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %%
voc_path = '/Users/ke/Downloads/VOCdevkit/VOC2007'
class_mapping = voc_data_helpers.get_class_mapping(voc_path)
img, img_metadata = voc_data_helpers.extract_img_data(voc_path, '001915')
image = voc_data_helpers.extract_img_data_2(voc_path, '000005')
print(image.data.shape)
image = image.resize_min_side(RESIZE_MIN_SIDE)
new_width, new_height = resized_dims(image.width, image.height, 600)
rgb_image = cv2.cvtColor(image.data, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)
batched_img = np.expand_dims(image.data, axis=0)
# Out:
# (375, 500, 3)

# %%
json_file = open('../models/model_rpn.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model_rpn = model_from_json(loaded_model_json)
model_rpn.load_weights('../models/rpn_weights_tmp.h5')

# %%
cls_out, regr_out = model_rpn.predict_on_batch(batched_img)

# %%
box_coords = get_rois_3(regr_out, ANCHOR_DIMS)

# %%
all_boxes = box_coords
all_probs = cls_out.reshape((-1))

# %%
filtered_boxes = nms(all_boxes, all_probs, max_boxes=300)

# %%
y_cls, y_reg = rpn_y_true_batch(image)

# %%
rois, y_class_num, y_transform, ious = get_ious_3(filtered_boxes, img_metadata, class_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-cc79ed32159b> in <module>()
# ----> 1 rois, y_class_num, y_transform, ious = get_ious_3(filtered_boxes, img_metadata, class_mapping)
#
# NameError: name 'get_ious_3' is not defined

# %%
img_input = Input(shape=(None, None, 3))
roi_input = Input(shape=(None, 4))
classifier = vgg16_classifier(64, 20 + 1, base_model = vgg16_base(21))
#model_classifier = Model(inputs=[img_input, roi_input], outputs=classifier)
model_classifier = classifier
model_classifier.compile(optimizer=SGD(lr=1e-3, momentum=0.9, clipnorm=1.), loss=[cls_loss_det, bbreg_loss_det(20)])
model_classifier.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_3 (InputLayer)             (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, None, None, 64 1792        input_3[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Conv2D)            (None, None, None, 64 36928       block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_pool (MaxPooling2D)       (None, None, None, 64 0           block1_conv2[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
rois, y_class_num, y_transform = det_y_true_batch_3(model_rpn, image, 64, class_mapping)

# %%
print(rois)
print(batched_img.shape)
print(rois.shape)
# Out:
# [[[25 17  5 11]
#   [24 17  5 11]
#   [24 19  5 11]
#   [18 26  8  8]
#   [27 21  5 11]
#   [24 21  5 11]
#   [ 0 22  8 14]
#   [15 28  8  8]
#   [25 21  8  8]
#   [22 22  8  8]
#   [22 19  8  8]
#   [26 24  5 11]
#   [23 19  5 11]
#   [24 22  8  8]
#   [17 25  8  8]
#   [23 21  8  8]
#   [17 29  8  7]
#   [24 24  8  8]
#   [17 27  8  8]
#   [ 0 28  8  8]
#   [26 20  5 11]
#   [ 0 25  6 11]
#   [15 25 11 11]
#   [24 20  8  8]
#   [25 21  5 11]
#   [12 27 16  9]
#   [26 22  5 11]
#   [18 28  8  8]
#   [25 19  5 11]
#   [25 25  8  8]
#   [25 23  8  8]
#   [16 26  5 10]
#   [ 2 31  5  5]
#   [20 17 16 16]
#   [ 2 25 11 11]
#   [18 21 11 15]
#   [19 19 16 16]
#   [ 0 20 21 16]
#   [ 0 25 23 11]
#   [17 23  5 11]
#   [23 14 11 22]
#   [19 25  8  8]
#   [15 24 16 12]
#   [ 0 14  8 16]
#   [ 0  8 13 28]
#   [ 0 17  8 16]
#   [22 18 11 18]
#   [23 17  5 11]
#   [28 11  5 11]
#   [21 21 28 15]
#   [ 0 31  5  5]
#   [19 27  5  9]
#   [26 19 11 17]
#   [22 30  8  6]
#   [22 15 16 16]
# ...

# %%
#json_file = open('../models/model_cls.json', 'r')
#loaded_model_json = json_file.read()
#json_file.close()
#model_cls = model_from_json(loaded_model_json, custom_objects={'RoiResizeConv': RoiResizeConv})
# load weights into new model
model_classifier.load_weights("../models/det_weights_tmp.h5")

# %%
cls_out_cls, cls_out_reg = model_classifier.predict_on_batch([batched_img, rois])

# %%
print(cls_out_cls[0,6])
print(class_mapping)
new_coords = transform(rois[0, 6], cls_out_reg[0,6,0:4])
new_coords = [new_coords]
print(new_coords)
# Out:
# [  5.55874109e-01   6.58473926e-14   3.42713613e-09   4.90514029e-09
#    2.24290420e-06   1.46640339e-11   1.00566055e-10   2.89943052e-11
#    1.05604089e-12   1.74432863e-02   3.32267192e-08   8.00437407e-12
#    1.36162442e-10   1.28138955e-09   2.84947593e-10   5.68454084e-09
#    1.11278432e-07   2.37834557e-12   1.47748463e-11   4.80190757e-12
#    4.26680118e-01]
# {'sofa': 16, 'pottedplant': 14, 'bird': 11, 'motorbike': 13, 'chair': 0, 'boat': 15, 'train': 7, 'bg': 20, 'cat': 5, 'tvmonitor': 10, 'person': 3, 'aeroplane': 8, 'car': 1, 'horse': 2, 'sheep': 17, 'bus': 19, 'bicycle': 4, 'cow': 18, 'dog': 6, 'bottle': 12, 'diningtable': 9}
# [(0.088440590925737084, 19.304897730464127, 8.448632789000424, 16.093067368041705)]

# %%
fig,ax = plt.subplots(1)
ax.imshow(batched_img[0])
for x1,y1,w,h in new_coords:
    x1 *= 16
    y1 *= 16
    w *= 16
    h *= 16
    rect = patches.Rectangle((x1, y1), w, h, linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)
